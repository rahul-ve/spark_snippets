# %%
# %scala
val checkCPdir = sc.getCheckpointDir
if (checkCPdir.isEmpty) {
  sc.setCheckpointDir("dbfs:/mnt/common/checkpoint")
  println("Checkpoint directory set!")
} else {
  println("Checkpoint directory already set!")
}
